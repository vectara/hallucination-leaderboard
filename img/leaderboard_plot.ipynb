# %%
# Manually append results for new models

results = {
    "GPT-4o": 0.015,
    "GPT-4-Turbo": 0.017,
    "GPT-4o-mini": 0.017,
    "GPT-4": 0.018,
    "GPT-3.5-Turbo": 0.019,
    "Orca-2-13B": 0.025,
    "Snowflake-Arctic-Instruct": 0.03,
    "Phi-3-Mini-128K-Instruct": 0.031,
    "Phi-3-Mini-4K-Instruct": 0.04,
    "Llama-3-70B-chat-hf": 0.041,
    "Mixtral-8x22B-Instruct-v0.1": 0.047,
    "Llama-2-70B-Chat-hf": 0.059,
    "Gemini-1.5-flash": 0.066,
    "Phi-2": 0.067,
    "Llama-3-8B-chat-hf": 0.074,
    "Gemini-Pro": 0.077,
    "C4AI-Command-R+": 0.078,
    "DBRX-Instruct": 0.083,
    "Claude-3-5-sonnet": 0.086,
    "Claude-3-opus": 0.101,
    "Gemma-2-9B-it": 0.101,
    "Llama-2-13B-Chat-hf": 0.105,
    "Llama-2-7B-Chat-hf": 0.113,
    "WizardLM-2-8x22B": 0.117,
    "Titan-Express": 0.135,
    "PaLM-2": 0.141,
    "Gemma-7B-it": 0.148,
    "Cohere-Chat": 0.154,
    "Claude-3-sonnet": 0.163,
    "gemma-1.1-7b-it": 0.17,
    "Claude-2": 0.174,
    "Flan-T5-large": 0.183,
    "Cohere": 0.189,
    "Mixtral-8x7B-Instruct-v0.1": 0.201,
    "OpenELM-3B-Instruct": 0.248,
    "gemma-1.1-2b-it": 0.278,
    "Gemini-1.5-Pro": 0.281,
    "Falcon-7B-Instruct": 0.299,
    "PaLM-2-Chat": 0.698,
    "Llama-3.1-8B-Instruct": 0.055,
    "Llama-3.1-70B-Instruct": 0.05,
    "Llama-3.1-405B-Instruct": 0.039,
    "Mistral-Large2": 0.044,
    "Intel-Neural-Chat-7B-v3-3": 0.027,
    "GLM-4-9B-Chat": 0.016,
    "Yi-1.5-34B-Chat": 0.039,
    "Qwen2-72B-Instruct": 0.049,
    "Yi-1.5-6B-Chat": 0.082,
    "Yi-1.5-9B-Chat": 0.05,
    "Gemma-2-2B-it": 0.07,
    "Mistral-7B-Instruct-v0.3": 0.098
}

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.DataFrame.from_dict(results, orient='index', columns=["hallucination_rate"])
df = (df*100).round(2)
df_sorted = df.sort_values(by='hallucination_rate', ascending=True).head(25).reset_index()
df_sorted.columns = ['LLM','hallucination_rate']


plt.figure(figsize=(10, 6))
ax = sns.barplot(x='hallucination_rate', y='LLM', data=df_sorted,
                 palette='Spectral_r', orient='h')
plt.title('Hallucination Rate for Top 25 LLMs',pad=25)
ax.set_xlabel('')
ax.set_ylabel('')

# Add value labels on the bars
for i, v in enumerate(df_sorted['hallucination_rate']):
    ax.text(v + 0.1, i, f'{v:.1f}%', va='center')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Set x-axis limit
ax.set_xlim(0, 10)

plt.tight_layout()
plt.savefig('hallucination_rates_of_various_LLMs.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_1340396/1868375746.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='hallucination_rate', y='LLM', data=df_sorted,
